# %%
import requests
import bs4

# %%
requests.__version__
# Out:
# '2.23.0'

# %%
bs4.__version__
# Out:
# '4.9.1'

# %%
from datetime import datetime

datetime.now()
# Out:
# datetime.datetime(2020, 5, 31, 9, 25, 21, 846892)

# %%
html = requests.get('http://www.blucean.net')
html
# Out:
# <Response [200]>

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n<head>\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=UA-109282531-1"></script>\n\t<script>\n\twindow.dataLayer = window.dataLayer || [];\n\tfunction gtag(){dataLayer.push(arguments);}\n\tgtag(\'js\', new Date());\n\n\tgtag(\'config\', \'UA-109282531-1\');\n\t</script>\n\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta name="description" content="ë\x8d\x94ë¸\x94ë£¨ì\x85\x98 í\x99\x88í\x8e\x98ì\x9d´ì§\x80 - Deep Creation in Service and Technology">\n    <meta name="author" content="ë\x8d\x94ë¸\x94ë£¨ì\x85\x98">\n    <meta name="keyword" content="ë\x8d\x94ë¸\x94ë£¨ì\x85\x98,ì\x84\x9cë¹\x84ì\x8a¤ í\x94\x8cë\x9e«í\x8f¼,ë§\x88ì¼\x80í\x8c\x85 í\x94\x8cë\x9e«í\x8f¼,ëª¨ë°\x94ì\x9d¼ í\x94\x8cë\x9e«í\x8f¼,ë¹\x85ë\x8d°ì\x9d´í\x84°,moreBlucean,blucean.net,">\n\
# ...

# %%
html.headers
# Out:
# {'Date': 'Sun, 31 May 2020 00:26:40 GMT', 'Server': 'Apache', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html'}

# %%
html.encoding
# Out:
# 'ISO-8859-1'

# %%
html.encoding = 'utf-8'
html.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n<head>\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=UA-109282531-1"></script>\n\t<script>\n\twindow.dataLayer = window.dataLayer || [];\n\tfunction gtag(){dataLayer.push(arguments);}\n\tgtag(\'js\', new Date());\n\n\tgtag(\'config\', \'UA-109282531-1\');\n\t</script>\n\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta name="description" content="더블루션 홈페이지 - Deep Creation in Service and Technology">\n    <meta name="author" content="더블루션">\n    <meta name="keyword" content="더블루션,서비스 플랫폼,마케팅 플랫폼,모바일 플랫폼,빅데이터,moreBlucean,blucean.net,">\n\n    <title>더블루션 - Deep Creation in Service and Technology</title>\n\n    <!-- Bootstrap Core CSS -->\n    <link href="css/bootstrap.min.css" rel="stylesheet">\n\n    <!-- Custom Fonts -->\n    <link href="vendor/font
# ...

# %%
html.status_code
# Out:
# 200

# %%
html.ok
# Out:
# True

# %%
import requests 
from bs4 import BeautifulSoup

response = requests.get('http://www.blucean.net')
response.encoding= 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

# f = open('text.html', 'w', encoding='utf-8')
# f.write(html)
# f.close()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-109282531-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-109282531-1');
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="더블루션 홈페이지 - Deep Creation in Service and Technology" name="description"/>
#   <meta content="더블루션" name="author"/>
#   <meta content="더블루션,서비스 플랫폼,마케팅 플랫폼,모바일 플랫폼,빅데이터,moreBlucean,blucean.net," name="keyword"/>
#   <title>
#    더블루션 - Deep Creation in Service and Technology
#   </title>
#   <!-- Bootstrap Core CSS -->
#   <link href="css/bootstrap.min.css" rel="stylesheet"/>
#   <!-- Custom Fonts -->
# ...

# %%
soup.title
# Out:
# <title>더블루션 - Deep Creation in Service and Technology</title>

# %%
soup.title.string  #soup.title.text
# Out:
# '더블루션 - Deep Creation in Service and Technology'

# %%
soup.select('.text-muted')
# Out:
# [<p class="text-muted">멤버십, 쿠폰, 신용카드를 통합 관리하는 모바일 전자지갑 서비스인 CLiP을 비롯하여 KT 모바일 고객 포탈 서비스를 통하여 최적의 기술을 제공하는 모바일 애플리케이션 비즈니스</p>,
#  <p class="text-muted">마케팅 인사이트 플랫폼, 고객 인증 플랫폼, 통합 전자지갑 플랫폼, 전기차 충전 플랫폼 등의 서비스 및 인프라 구축 경험을 통한 서비스 플랫폼 비즈니스</p>,
#  <p class="text-muted">빅데이터 수집, 저장, 처리, 분석 및 시각화를 통한 이용현황, 추이분석, 연관분석 및 예측 분석 등의 분석모델 개발과 데이터 분석 플랫폼을 기반으로 한 개인화 타겟 서비스를 위한 마케팅 비즈니스</p>,
#  <p class="text-muted">CLiP 모바일 전자지갑 서비스</p>,
#  <p class="text-muted">고객 마케팅 인사이트 플랫폼</p>,
#  <p class="text-muted">데이터 수집/처리/분석 플랫폼</p>,
#  <p class="text-muted">전기차 충천 플랫폼</p>,
#  <p class="text-muted">서비스 통합 인증 플랫폼</p>,
#  <p class="text-muted">모바일/웹 서비스</p>,
#  <p class="text-muted">데이터 분석 솔루션</p>,
#  <p class="text-muted">연관상품 추천 솔루션</p>,
#  <p class="text-muted">빅데이터 의사결정 솔루션</p>,
#  <p class="text-muted">KT OTT플랫폼(SEEZN) 운영·유지보수<em>(19.09)</em></p>,
#  <p class="text-muted">단국대 교육지식플랫폼/교육지원비서 구축<em>(19.09)</em></p>,
#  <p class="text-muted">챗봇 고도화 개발 <em>(19.06)</em></p>,
# ...
